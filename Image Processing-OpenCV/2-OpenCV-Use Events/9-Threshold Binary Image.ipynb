# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Make a binary image

# %%
img= cv2.imread('../Images/1.jpg', cv2.IMREAD_GRAYSCALE)

new_img= np.copy(img)
new_img[new_img < 127] = 0
new_img[new_img >= 127] = 255

plt.figure(figsize= [10, 5])
plt.subplot(121);plt.imshow(img, cmap='gray');plt.title('Original')
plt.subplot(122);plt.imshow(new_img, cmap='gray');plt.title('Output')
# Out:
# Text(0.5, 1.0, 'Output')

# %%
max_val= 255
max_type= 4
max_bi_val= 255
track_type= 'Type: \n 0: Binary \n 1: Binary Inverted \n 2: Truncate \n 3: To Zero \n 4: To Zero Inverted'
track_val= 'Value'
win_name= 'Threshold Demo'

def threshold_Demo(val):
    global dst, threshold_val, threshold_type
    
    threshold_type = cv2.getTrackbarPos(track_type, win_name)
    threshold_val = cv2.getTrackbarPos(track_val, win_name)
    _, dst= cv2.threshold(src_gray, threshold_val, max_bi_val, threshold_type)
    cv2.imshow(win_name, dst)
    
src= cv2.imread('../Images/2.jpg')

src_gray= cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
cv2.namedWindow(win_name, cv2.WINDOW_NORMAL)
cv2.resizeWindow(win_name, 400, 300)
cv2.createTrackbar(track_type, win_name, 3, max_type, threshold_Demo)
cv2.createTrackbar(track_val, win_name, 0, max_val, threshold_Demo)

threshold_Demo(0)

cv2.waitKey()
cv2.destroyAllWindows()

thresh_type= ["Binary", "Binary Inverted", "Threshold Trunvated", "Threshold To Zero", "Threshold To Zero Inverted"]
plt.imshow(dst, cmap='gray');plt.title("Threshold: {} with type: {}".format(threshold_val, thresh_type[threshold_type]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 12, in threshold_Demo(val)
#       9 global dst, threshold_val, threshold_type
#      11 threshold_type = cv2.getTrackbarPos(track_type, win_name)
# ---> 12 threshold_val = cv2.getTrackbarPos(track_val, win_name)
#      13 _, dst= cv2.threshold(src_gray, threshold_val, max_bi_val, threshold_type)
#      14 cv2.imshow(win_name, dst)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:868: error: (-215:Assertion failed) trackbar in function 'cv::getTrackbarPos'
